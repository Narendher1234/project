# %%
import pandas as pd
dict={"Nmaes":["ravi","ramesh","narendher","manasa"],
     "couses":["python","java","dotnet","oracle"],
     "fees":[6500,2500,4500,5500]}

df=pd.DataFrame(dict)
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        Nmaes  couses  fees
# 0       ravi  python  6500
# 1     ramesh    java  2500
# 2  narendher  dotnet  4500
# 3     manasa  oracle  5500

# %% [raw]
# # creating dataframe by using csv files

# %%
import pandas as pd
path=" "
s=pd.read_csv(path)
print(s)
